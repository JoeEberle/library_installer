# %% [markdown]
# ![library_installer.png](attachment:library_installer.png)

# %% [markdown]
# ![library_installation.png](attachment:library_installation.png)

# %% [markdown]
# # Step 1 - Update and Install any libraries you need.  There is no harm in updateing to the latest version. There is no harm in adding more libraries !

# %% [markdown]
# ![developer.png](attachment:developer.png)

# %%
# List of libraries to install
libraries_to_install = [
    "PyGithub",
    "requests",
    "pyttsx3",
    "sklearn",
    "ydata_profiling",
    "configparser",
    "schedule",
    "pandas",
    "pyarrow",
    "fastparquet",
    "glob2",
    "pathlib",
    "pyodbc",
    "sqlalchemy",
    "datetime",
    "json",    
    "ipynbname"
]

# Flag to indicate whether it's the first installation
first_install = True

# Flag to indicate whether to upgrade to the latest version
upgrade_to_latest = False

# Iterate through the libraries and install or upgrade each one
for library in libraries_to_install:
    if first_install or upgrade_to_latest:
        # !pip install --upgrade {library}
# Out:
# ...
#      -------------------------------------- 342.2/342.2 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: PyGithub
#     Found existing installation: PyGithub 1.59.0
#     Uninstalling PyGithub-1.59.0:
#       Successfully uninstalled PyGithub-1.59.0
# ...
#      ---------------------------------------- 62.6/62.6 kB 1.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.0.0 requires requests<2.29,>=2.24.0, but you have requests 2.31.0 which is incompatible.
# streamlit 0.85.1 requires click<8.0,>=7.0, but you have click 8.1.7 which is incompatible.
# panel 0.14.2 requires bokeh<2.5.0,>=2.4.0, but you have bokeh 2.2.3 which is incompatible.
# ...

# %% [markdown]
# # Step 2 - Import all the libraries used in the entire suite of solutions to make sure you have everything !! Import more libraries if you want. VISUALLY INSPECT and look for errors - you should get no errors!!!!

# %%
# Import the necessary Libraries 
import webbrowser as wb
import configparser as cg 
import schedule as sc
import time as time
import datetime as datetime
import pyttsx3 as td 
import ipynbname as nb 
import pandas as pd 
import pyarrow
import fastparquet
import glob 
import os
import pathlib
import pyodbc

# %% [markdown]
# # Step 3 - Import any custom (non standard) libraries used !! Import more libraries if you want. VISUALLY INSPECT and look for errors - you should get no errors!!!

# %%
import talking_code as tc

# %% [markdown]
# ## This <b><u>OPTIONAL</u></b> step produces <b><u>OPTIONAL</u></b> documentation and  <b><u>OPTIONAL</u></b> education . This step will document if documenting is set to True in the configuration file. This step will only explain itself to you via text to speech if Talking_code is set to True.

# %%
import talking_code as tc 

talking_code = True
if talking_code:
    tc.print_say("This jupiter notebook will install and update all libraries. You can easily extended this to any libraries you choose.")
else:
    print("This jupiter notebook will install and update all libraries. You can easily extended this to any libraries you choose.")
# Out:
# This jupiter notebook will install and update all libraries. You can easily extended this to any libraries you choose.

# %%
if talking_code:
    tc.print_say("The high level steps for this solution are: ")
    tc.print_say("Step 1: pip install all libraries used. ")
    tc.print_say("Step 2: test all STANDARD libraries by importing them and visually inspecting for import errors.  ")
    tc.print_say("Step 3:test all NON STANDARD or custom libraries by importing them and visually inspecting for import errors. ")
else:
    print("The high level steps for this solution are: ")
    print("Step 1: pip install all libraries used. ")
    print("Step 2: test all STANDARD libraries by importing them and visually inspecting for import errors.  ")
    print("Step 3:test all NON STANDARD or custom libraries by importing them and visually inspecting for import errors. ")
# Out:
# The high level steps for this solution are:
# Step 1: pip install all libraries used.
# Step 2: test all STANDARD libraries by importing them and visually inspecting for import errors.
# Step 3:test all NON STANDARD or custom libraries by importing them and visually inspecting for import errors.

# %%
import json

# JSON data representing the notes
notes_json = '''
[
    {
        "title": "Note 1",
        "content": "This solution assumes that the entire development team is OK using the latest libraries and technologies. This may not be true and is personal preference. Some solutions may fail using this approach if the latest libraries are not backwardly compatible or methods are replaced or redacted. Some organizations or individuals may prefer to use virtual environments to avoid these types of issues. This is personal preference and an architecture decision for you to consider when choosing what's best for you or your organization."
    },
    {
        "title": "Note 2",
        "content": "This solution assumes that PIP is intelligent enough to determine if libraries are installed or outdated. PIP is the package installer for Python. PIP is the de facto and recommended package-management system written in Python and is used to install and manage software packages. It connects to an online repository of public packages, called the Python Package Index."
    },
    {
        "title": "Note 3",
        "content": "A monolithic (brute force) library update approach was chosen as the default approach for this solution, meaning that a comprehensive set of libraries is used for ALL solutions, however, there is nothing preventing you from creating and using individual library installers for each solution you develop. This is personal preference and an architecture decision for you to consider when choosing what's best for you or your organization."
    },
    {
        "title": "Note 4",
        "content": "This data science solution was developed in Python using Jupyter Notebook for ease of illustration and educational purposes. There is nothing preventing you from using your preferred language and integrated development environment (IDE) of your choice, such as Visual Studio or PyCharm. This solution was developed on a Windows platform and has not been tested on Linux or other operating systems; however, it was designed with cross-platform compatible libraries, so hypothetically the solution should be portable to other platforms."
    },
    {
        "title": "Note 5",
        "content": "The performance of this solution will vary greatly based upon how often it is run and how many libraries need installation or updating."
    },
    {
        "title": "Note 6",
        "content": "The solution also includes a section that tests custom (private) or non-standard PyPI publically compatible libraries. This section of the solution may be removed if it is not applicable to your solutions."
    }
]
'''

# Load the JSON into a Python variable called 'notes'
notes = json.loads(notes_json)

# Iterate through and print the notes
if talking_code:
    for note in notes:
        tc.print_say(f"{note['title']}")
        tc.print_say(f"{note['content']}\n")
else:        
    for note in notes:
        print(f"Title: {note['title']}")
        print(f"Content: {note['content']}\n")
# Out:
# Note 1
# This solution assumes that the entire development team is OK using the latest libraries and technologies. This may not be true and is personal preference. Some solutions may fail using this approach if the latest libraries are not backwardly compatible or methods are replaced or redacted. Some organizations or individuals may prefer to use virtual environments to avoid these types of issues. This is personal preference and an architecture decision for you to consider when choosing what's best for you or your organization.
#
# Note 2
# This solution assumes that PIP is intelligent enough to determine if libraries are installed or outdated. PIP is the package installer for Python. PIP is the de facto and recommended package-management system written in Python and is used to install and manage software packages. It connects to an online repository of public packages, called the Python Package Index.
#
# Note 3
# ...
